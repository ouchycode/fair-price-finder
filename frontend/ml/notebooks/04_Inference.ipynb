# %% [markdown]
# # 04 - Model Inference
# **Fair Price Finder - CC26-PSU164**
#
# Load model yang telah dilatih dan jalankan prediksi sederhana.

# %%
import sys
sys.path.append('../src')
from models.deep_learning_model import load_and_infer

# Contoh inference
# features = preprocess('Web Development', ['React', 'Node.js'], duration=14)
# result = load_and_infer('../saved_models/price_model.keras', features)
# print(result)
